# %%
# import packages
import PyPDF2
import re

# open the pdf file
object = PyPDF2.PdfFileReader("Report_Detail_Metrics.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String = "Sales"

# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    print("this is page " + str(i)) 
    Text = PageObj.extractText() 
    # print(Text)
    ResSearch = re.search(String, Text)
    print(ResSearch)
# Out:
# this is page 0
# <re.Match object; span=(133, 138), match='Sales'>
# this is page 1
# None
# this is page 2
# <re.Match object; span=(1305, 1310), match='Sales'>
# this is page 3
# None
# this is page 4
# None
# this is page 5
# None
# this is page 6
# <re.Match object; span=(1416, 1421), match='Sales'>
# this is page 7
# <re.Match object; span=(628, 633), match='Sales'>

# %%
import PyPDF2#Now give the pdf 
pdfFileObj = open('Report_Detail_Metrics.pdf', 'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
print(pdfReader.numPages) # will give total number of pages in pdf
# Out:
# 8

# %%
# pip install textract

# %%
import os
dir_path='D:/Testing_pdf_files/'
os.chdir(dir_path)

import PyPDF2
file_list=os.listdir()

file_list
# Out:
# ['MedCity_AIeBook_MCM146_R1.pdf', 'Report_Detail_Metrics.pdf']

# %%
file_list=os.listdir()
for file_name in file_list:
    
    pdfFileObj=open(dir_path+file_name, 'rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj, strict=False)

    
    search_word = "health"
    search_word_count = 0

    for pageNum in range(0, pdfReader.numPages):
        
        pageObj = pdfReader.getPage(pageNum)
        text = pageObj.extractText().encode('utf-8')
        search_text = text.lower().split()
        for word in search_text:
            if search_word in word.decode("utf-8"):
                search_word_count += 1
        
print("The word {} was found {} times".format(search_word, search_word_count))
# Out:
# The word health was found 2 times

# %%
import PyPDF2
pdfFileObj = open('Report_Detail_Metrics.pdf', 'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj, strict=False)

search_word = "sales"
search_word_count = 0

for pageNum in range(0, pdfReader.numPages):
    pageObj = pdfReader.getPage(pageNum)
    text = pageObj.extractText().encode('utf-8')
    search_text = text.lower().split()
    for word in search_text:
        if search_word in word.decode("utf-8"):
            search_word_count += 1
        
print("The word {} was found {} times".format(search_word, search_word_count))
# Out:
# The word sales was found 25 times

# %% [markdown]
# Source:https://connysoderholm.com/search-pdf-files-with-pypdf2/

# %% [markdown]
# <h2> Reading multiple pdf files

# %%
import os
dir_path='D:/Testing_pdf_files'
os.chdir(dir_path)

# %%
import PyPDF2
file_list=os.listdir()

# %%
file_list
# Out:
# ['MedCity_AIeBook_MCM146_R1.pdf',
#  'Merged_pdfs.pdf',
#  'Report_Detail_Metrics - Copy (10).pdf',
#  'Report_Detail_Metrics - Copy (100).pdf',
#  'Report_Detail_Metrics - Copy (101).pdf',
#  'Report_Detail_Metrics - Copy (102).pdf',
#  'Report_Detail_Metrics - Copy (103).pdf',
#  'Report_Detail_Metrics - Copy (104).pdf',
#  'Report_Detail_Metrics - Copy (105).pdf',
#  'Report_Detail_Metrics - Copy (106).pdf',
#  'Report_Detail_Metrics - Copy (107).pdf',
#  'Report_Detail_Metrics - Copy (108).pdf',
#  'Report_Detail_Metrics - Copy (109).pdf',
#  'Report_Detail_Metrics - Copy (11).pdf',
#  'Report_Detail_Metrics - Copy (110).pdf',
#  'Report_Detail_Metrics - Copy (111).pdf',
#  'Report_Detail_Metrics - Copy (112).pdf',
#  'Report_Detail_Metrics - Copy (113).pdf',
#  'Report_Detail_Metrics - Copy (114).pdf',
#  'Report_Detail_Metrics - Copy (115).pdf',
#  'Report_Detail_Metrics - Copy (116).pdf',
#  'Report_Detail_Metrics - Copy (117).pdf',
# ...

# %%
for file_name in file_list:
    f=open(dir_path+ file_name, 'rb')

# %%
import PyPDF2

for file_name in file_list:
    
    pdfFileObj = open(dir_path+ file_name, 'rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj, strict=False)

    search_word = "sales"
    search_word_count = 0

    for pageNum in range(0, pdfReader.numPages):
        
        pageObj = pdfReader.getPage(pageNum)
        text = pageObj.extractText().encode('utf-8')
        search_text = text.lower().split()
        for word in search_text:
            
            if search_word in word.decode("utf-8"):
                search_word_count += 1
        
print("The word {} was found {} times".format(search_word, search_word_count))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-113-1f0e393a9d22> in <module>
#       3 for file_name in file_list:
#       4
# ----> 5     pdfFileObj = open(dir_path+ file_name, 'rb')
#       6     pdfReader = PyPDF2.PdfFileReader(pdfFileObj, strict=False)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/Testing_pdf_filesMedCity_AIeBook_MCM146_R1.pdf'

# %%
import PyPDF2
pdfFileObj = open('Merged_Files.pdf', 'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj, strict=False)

search_word = "sales"
search_word_count = 0

for pageNum in range(0, pdfReader.numPages):
    pageObj = pdfReader.getPage(pageNum)
    text = pageObj.extractText().encode('utf-8')
    search_text = text.lower().split()
    for word in search_text:
        if search_word in word.decode("utf-8"):
            search_word_count += 1
        
print("The word {} was found {} times".format(search_word, search_word_count))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-115-b513874c13be> in <module>
#       1 import PyPDF2
# ----> 2 pdfFileObj = open('Merged_Files.pdf', 'rb')
#       3 pdfReader = PyPDF2.PdfFileReader(pdfFileObj, strict=False)
#       4
#       5 search_word = "sales"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Merged_Files.pdf'

# %%
for pageNum in range(0, len(file_list)):
    pageObj = pdfReader.getPage(pageNum)
    text = pageObj.extractText().encode('utf-8')
    search_text = text.lower().split()
    for word in search_text:
        if search_word in word.decode("utf-8"):
            search_word_count += 1
        
print("The word {} was found {} times".format(search_word, search_word_count))

# %%
import PyPDF2
import re

for k in range(1,100):
    # open the pdf file
    object = PyPDF2.PdfFileReader('D:/Testing_pdf_files/%s.pdf'%(k))

    # get number of pages
NumPages = object.getNumPages()

    # define keyterms
String = "health"

    # extract text and do the search
for i in range(0, NumPages):
    
    PageObj = object.getPage(i)
    print("this is page " + str(i)) 
    Text = PageObj.extractText() 
    # print(Text)
    ResSearch = re.search(String, Text)
    print(ResSearch)

# %%
import PyPDF2
import re

for k in range(1,100):
    # open the pdf file
    object = PyPDF2.PdfFileReader("D:/Testing_pdf_files/'.pdf"%(k))

    # get number of pages
    NumPages = object.getNumPages()

    # define keyterms
    String = "New York State Real Property Law"

    # extract text and do the search
    for i in range(0, NumPages):
        PageObj = object.getPage(i)
        print("this is page " + str(i)) 
        Text = PageObj.extractText() 
        # print(Text)
        ResSearch = re.search(String, Text)
        print(ResSearch)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-ddc830177606> in <module>
#       4 for k in range(1,100):
#       5     # open the pdf file
# ----> 6     object = PyPDF2.PdfFileReader("D:/Testing_pdf_files/''%s.pdf"%(k))
#       7
#       8     # get number of pages
#
# c:\Users\user\anaconda3\lib\site-packages\PyPDF2\pdf.py in __init__(self, stream, strict, warndest, overwriteWarnings)
#    1079             warnings.warn("PdfFileReader stream/file object is not in binary mode. It may not be read correctly.", utils.PdfReadWarning)
#    1080         if isString(stream):
# -> 1081             fileobj = open(stream, 'rb')
#    1082             stream = BytesIO(b_(fileobj.read()))
#    1083             fileobj.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: "D:/Testing_pdf_files/''1.pdf"

# %%
from glob import glob
from PyPDF2 import PdfFileMerger



def pdf_merge():
    ''' Merges all the pdf files in current directory '''
    merger = PdfFileMerger()
    allpdfs = [a for a in glob("*.pdf")]
    [merger.append(pdf) for pdf in allpdfs]
    with open("Merged_pdfs.pdf", "wb") as new_file:
        merger.write(new_file)


if __name__ == "__main__":
    pdf_merge()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-108-f6bc59791299> in <module>
#      14
#      15 if __name__ == "__main__":
# ---> 16     pdf_merge()
#
# <ipython-input-108-f6bc59791299> in pdf_merge()
#       8     merger = PdfFileMerger()
#       9     allpdfs = [a for a in glob("*.pdf")]
# ---> 10     [merger.append(pdf) for pdf in allpdfs]
#      11     with open("Merged_pdfs.pdf", "wb") as new_file:
#      12         merger.write(new_file)
#
# <ipython-input-108-f6bc59791299> in <listcomp>(.0)
#       8     merger = PdfFileMerger()
#       9     allpdfs = [a for a in glob("*.pdf")]
# ---> 10     [merger.append(pdf) for pdf in allpdfs]
#      11     with open("Merged_pdfs.pdf", "wb") as new_file:
#      12         merger.write(new_file)
#
# c:\Users\user\anaconda3\lib\site-packages\PyPDF2\merger.py in append(self, fileobj, bookmark, pages, import_bookmarks)
# ...
